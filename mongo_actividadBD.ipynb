# %% [markdown]
# # **Actividad Mongo**
# ##Luis Alejandro Camacho Benitez

# %%
# !pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.17.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)

# %%
from pymongo import MongoClient

# %%
cliente = MongoClient("mongodb+srv://luisalejandrobenitez20_db_user:1tE49vbXuMS7ph4d@cluster1.9ics7hp.mongodb.net/")

# %%
try:
    cliente.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = cliente["BD_CursoMongo"]

estudiantes = db["Estudiantes"]

# %% [markdown]
# # Funciones CRUD básicas

# %%
#Insertar un estudiante
def insertar_estudiante(nombre, edad, carrera):
    estudiante = {"nombre": nombre, "edad": edad, "carrera": carrera}
    estudiantes.insert_one(estudiante)
    print(f"Estudiante {nombre} insertado.")

# %%
# Listar estudiantes
def listar_estudiantes():
    print("Listado de estudiantes:")
    for est in estudiantes.find():
        print(est)

# %%
# Actualizar edad de un estudiante
def actualizar_edad(nombre, nueva_edad):
    estudiantes.update_one({"nombre": nombre}, {"$set": {"edad": nueva_edad}})
    print(f"Edad de {nombre} actualizada.")

# %%
# Eliminar un estudiante
def eliminar_estudiante(nombre):
    estudiantes.delete_one({"nombre": nombre})
    print(f"Estudiante {nombre} eliminado.")

# %% [markdown]
# Realizar un menú de opciones
# --- MENÚ DE ESTUDIANTES ---
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir

# %%
def menu():
    while True:
        print("\n MENÚ DE ESTUDIANTES ")
        print("1. Insertar estudiante")
        print("2. Listar estudiantes")
        print("3. Actualizar edad de un estudiante")
        print("4. Eliminar estudiante")
        print("5. Salir")

        opcion = input("\nElige una opción: ")

        if opcion == "1":
            nombre = input("Nombre del estudiante: ")
            edad = int(input("Edad: "))
            carrera = input("Carrera: ")
            insertar_estudiante(nombre, edad, carrera)

        elif opcion == "2":
            listar_estudiantes()

        elif opcion == "3":
            nombre = input("Nombre del estudiante a actualizar: ")
            nueva_edad = int(input("Nueva edad: "))
            actualizar_edad(nombre, nueva_edad)

        elif opcion == "4":
            nombre = input("Nombre del estudiante a eliminar: ")
            eliminar_estudiante(nombre)

        elif opcion == "5":
            print("Adios, hasta pronto")
            break

        else:
            print("Opción no válida. Intenta de nuevo.")
menu()
# Out:
#  MENÚ DE ESTUDIANTES
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir
#
# Elige una opción: 1
# Nombre del estudiante: Luis
# Edad: 19
# Carrera: Ciencia de datos
# Estudiante Luis insertado.
#
#  MENÚ DE ESTUDIANTES
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir
#
# Elige una opción: 3
# Nombre del estudiante a actualizar: Luis
# Nueva edad: 18
# Edad de Luis actualizada.
#
#  MENÚ DE ESTUDIANTES
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir
#
# Elige una opción: 2
# Listado de estudiantes:
# {'_id': ObjectId('69efea1fe78317f08d9346ba'), 'nombre': 'Luis', 'edad': 18, 'carrera': 'Ciencia de datos'}
#
#  MENÚ DE ESTUDIANTES
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir
#
# Elige una opción: 4
# Nombre del estudiante a eliminar: Luis
# Estudiante Luis eliminado.
#
#  MENÚ DE ESTUDIANTES
# 1. Insertar estudiante
# 2. Listar estudiantes
# 3. Actualizar edad de un estudiante
# 4. Eliminar estudiante
# 5. Salir
#
# Elige una opción: 5
# Adios, hasta pronto
